# %% [markdown]
# ## Data Engineering

# %%
import pandas as pd       # importing pandas library

# %%
employee = pd.DataFrame({"Name": ["Sofia", "Valentina", "Isabella"], "ID": [1,2,3]})         # Two Key Value Pair
employee      # printing an object
# Out:
#         Name  ID
# 0      Sofia   1
# 1  Valentina   2
# 2   Isabella   3

# %% [markdown]
# ## Data Loading / Data Acquisition

# %%
monkeypox = pd.read_csv('datasets\monkeypox.csv')
monkeypox
# Out:
# C:\Users\Abbas\AnaConda\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (3,7,8,10,11,12,13,14,16,18,19,20,21,22,23,24,25,28,29) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#           ID     Status                             Location    City  \
# 0         N1  confirmed  Guy's and St Thomas Hospital London  London
# 1         N2  confirmed  Guy's and St Thomas Hospital London  London
# 2         N3  confirmed                               London  London
# 3         N4  confirmed                               London  London
# 4         N5  confirmed                               London  London
# ...      ...        ...                                  ...     ...
# 17860  E1834  confirmed                                  NaN     NaN
# 17861  E1835  confirmed                                  NaN     NaN
# ...

# %% [markdown]
# ## Extracting Individual Column

# %%
monkeypox_region = monkeypox[['Country','City']]
monkeypox_region
# Out:
#                                 Country    City
# 0                               England  London
# 1                               England  London
# 2                               England  London
# 3                               England  London
# 4                               England  London
# ...                                 ...     ...
# 17860  Democratic Republic Of The Congo     NaN
# 17861  Democratic Republic Of The Congo     NaN
# 17862  Democratic Republic Of The Congo     NaN
# 17863  Democratic Republic Of The Congo     NaN
# 17864  Democratic Republic Of The Congo     NaN
#
# [17865 rows x 2 columns]

# %% [markdown]
# ## Extracting Individual Records

# %%
monkeypox['Gender']=='male'
# Out:
# 0        False
# 1        False
# 2        False
# 3         True
# 4         True
#          ...
# 17860    False
# 17861    False
# 17862    False
# 17863    False
# 17864    False
# Name: Gender, Length: 17865, dtype: bool

# %%
monkeypox_gender = monkeypox[monkeypox['Gender']=='male']
monkeypox_gender
# Out:
#            ID     Status   Location       City   Country Country_ISO3    Age  \
# 3          N4  confirmed     London     London   England          GBR    NaN
# 4          N5  confirmed     London     London   England          GBR    NaN
# 5          N6  confirmed     London     London   England          GBR    NaN
# 6          N7  confirmed  Newcastle  Newcastle   England          GBR    NaN
# 7          N8  confirmed     Lisbon     Lisbon  Portugal          PRT  20-44
# ...       ...        ...        ...        ...       ...          ...    ...
# 15806  N15807  confirmed        NaN        NaN    Sweden          SWE  20-65
# 15807  N15808  confirmed        NaN        NaN    Sweden          SWE  20-65
# 15808  N15809  confirmed        NaN        NaN    Sweden          SWE  20-65
# 15809  N15810  confirmed        NaN        NaN    Sweden          SWE  20-65
# 16167    E141  confirmed      Lagos        NaN   Nigeria          NGA  40-49
#
# ...

# %%
monkeypox.plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>
